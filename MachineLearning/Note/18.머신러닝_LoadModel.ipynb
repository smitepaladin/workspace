# %% [markdown]
# ### SVM

# %%
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
clf = joblib.load("../Data/svm_iris.h5")

# %%
clf.predict(
  [[5.1, 3.0, 1.3, 0.2]]
)[0]
# Out:
# 'Iris-setosa'

# %% [markdown]
# ### RandomForest

# %%
clf = joblib.load("../Data/random_forest_iris.h5")

# %%
import pandas as pd
iris = pd.read_csv("../Data/iris.csv")

# %%
clf.predict(
  [[5.1 / iris['SepalLength'].max() ,3.0/ iris['SepalWidth'].max(),1.3 / iris['PetalLength'].max(),0.2/ iris['PetalWidth'].max()]]
)[0]
# Out:
# 'Iris-setosa'
