# %% [markdown]
# ### 튜플(Tuple)자료형
# : 튜플은 다음과 같은 점을 제외하고는 리스트와 거의 비슷하다.
# - (와)로 사용
# - 튜플은 값을 변경할 수 없다.

# %%
# Tuple의 선언
var01 = ()
var02 = (1,)
var03 = (1,2,3)
var04 = 1,2,3
var05 = ('a','b',('ab', 'cd'))



type(var02)
# Out:
# tuple

# %%
var05[-1][0]
# Out:
# 'ab'

# %% [markdown]
# ### Tuple 값 변경
# : Tuple에 List를 추가하여 사용

# %%
tuple01 = ([1,2],3,4)
tuple01[0][0] = 100
print(tuple01)
# Out:
# ([100, 2], 3, 4)
