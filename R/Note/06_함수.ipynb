# %%
dan <-3
for(i in 1:9){
  cat(dan, "X", i, '=', dan*i, "\n")
}
# Out:
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27

# %%
gugu <- function(){
  for(i in 1:9){
    cat(dan, "X", i, '=', dan*i, "\n")
  }
}

# %%
gugu()
# Out:
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27

# %%
gugu <- function(dan){
  for(i in 1:9){
    cat(dan, "X", i, '=', dan*i, "\n")
  }
}

# %%
gugu(4)
# Out:
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
