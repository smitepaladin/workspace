# %%
import pandas as pd
import numpy as np
# 모든 컬럼 이름을 다 보여주기
pd.set_option('display.max_columns', None)

# 컬럼 하나당 표시할 최대 문자열 길이 제한 없애기
pd.set_option('display.max_colwidth', None)

# 콘솔 폭에 맞춰 자동 줄바꿈 없이 쭉 출력하기
pd.set_option('display.expand_frame_repr', False)

# 전역 출력 포맷 설정: 소수점 2자리 일반 실수 표기
pd.set_option('display.float_format', '{:.7f}'.format)

# %%
# 데이터 불러오기 

bus_station = pd.read_csv("../Data/TPSS_정류장_노선_정보_시간.csv")
bus_station.tail()
# Out:
#              기준일       노선ID     노선명      노선유형      정류장ID         정류장명     정류장유형         정류장번호  버스운행횟수(일)  버스운행횟수00H  버스운행횟수01H  버스운행횟수02H  버스운행횟수03H  버스운행횟수04H  버스운행횟수05H  버스운행횟수06H  버스운행횟수07H  버스운행횟수08H  버스운행횟수09H  버스운행횟수10H  버스운행횟수11H  버스운행횟수12H  버스운행횟수13H  버스운행횟수14H  버스운행횟수15H  버스운행횟수16H  버스운행횟수17H  버스운행횟수18H  버스운행횟수19H  버스운행횟수20H  버스운행횟수21H  버스운행횟수22H  버스운행횟수23H  승차승객수  하차승객수  승차승객수량00H  하차승객수량00H  승차승객수량01H  하차승객수량01H  승차승객수량02H  하차승객수량02H  승차승객수량03H  하차승객수량03H  승차승객수량04H  하차승객수량04H  승차승객수량05H  하차승객수량05H  승차승객수량06H  하차승객수량06H  승차승객수량07H  하차승객수량07H  승차승객수량08H  하차승객수량08H  승차승객수량09H  하차승객수량09H  승차승객수량10H  하차승객수량10H  승차승객수량11H  하차승객수량11H  승차승객수량12H  하차승객수량12H  승차승객수량13H  하차승객수량13H  승차승객수량14H  하차승객수량14H  승차승객수량15H  하차승객수량15H  승차승객수량16H  하차승객수량16H  승차승객수량17H  하차승객수량17H  승차승객수량18H  하차승객수량18H  승차승객수량19H  하차승객수량19H  승차승객수량20H  하차승객수량20H  승차승객수량21H  하차승객수량21H  승차승객수량22H  하차승객수량22H  승차승객수량23H  하차승객수량23H  정류장순서
# ...

# %%
# 정류장명이 '한남대교전망카페'인 행만 필터링
filtered_df = bus_station[bus_station['정류장명'] == '한남대교전망카페']

filtered_df.head()
# Out:
#             기준일       노선ID  노선명      노선유형      정류장ID      정류장명     정류장유형         정류장번호   버스운행횟수(일)  버스운행횟수00H  버스운행횟수01H  버스운행횟수02H  버스운행횟수03H  버스운행횟수04H  버스운행횟수05H  버스운행횟수06H  버스운행횟수07H  버스운행횟수08H  버스운행횟수09H  버스운행횟수10H  버스운행횟수11H  버스운행횟수12H  버스운행횟수13H  버스운행횟수14H  버스운행횟수15H  버스운행횟수16H  버스운행횟수17H  버스운행횟수18H  버스운행횟수19H  버스운행횟수20H  버스운행횟수21H  버스운행횟수22H  버스운행횟수23H       승차승객수      하차승객수  승차승객수량00H  하차승객수량00H  승차승객수량01H  하차승객수량01H  승차승객수량02H  하차승객수량02H  승차승객수량03H  하차승객수량03H  승차승객수량04H  하차승객수량04H  승차승객수량05H  하차승객수량05H  승차승객수량06H  하차승객수량06H  승차승객수량07H  하차승객수량07H  승차승객수량08H  하차승객수량08H  승차승객수량09H  하차승객수량09H  승차승객수량10H  하차승객수량10H  승차승객수량11H  하차승객수량11H  승차승객수량12H  하차승객수량12H  승차승객수량13H  하차승객수량13H  승차승객수량14H  하차승객수량14H  승차승객수량15H  하차승객수량15H  승차승객수량16H  하차승객수량16H  승차승객수량17H  하차승객수량17H  승차승객수량18H  하차승객수량18H  승차승객수량19H  하차승객수량19H  승차승객수량20H  하차승객수량20H  승차승객수량21H  하차승객수량21H  승차승객수량22H  하차승객수량22H  승차승객수량23H  하차승객수량23H  정류장순서
# ...

# %%
filtered_df.기준일.unique()
# Out:
# array([20250809, 20250808])
